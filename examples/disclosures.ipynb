# %% [markdown]
# # PSE disclosures

# %%
from fastquant import DisclosuresPSE

# %% [markdown]
# ## fetching company disclosures

# %%
dpse = DisclosuresPSE(symbol='JFC', 
                      start_date='1-1-2020', 
                      end_date='4-1-2020'
                     )
# Out:
# Pulling JFC disclosures summary...
#   0%|          | 0/10 [00:00<?, ?it/s]
# 1 pages detected!
# Found 10 disclosures between 1-1-2020 & 4-1-2020 with 3 types:
# ['Press Release' 'Material Information/Transactions' 'Joint Ventures']
# Pulling details in all JFC disclosures...
# 100%|██████████| 10/10 [00:11<00:00,  1.19s/it]
# Loaded: /home/jp/github/research/project/fastquant/fastquant/../data/JFC_disclosures_01-01-2018_01-04-2020.csv
# Deleted: /home/jp/github/research/project/fastquant/fastquant/../data/JFC_disclosures_01-01-2018_01-04-2020.csv
# Saved: /home/jp/github/research/project/fastquant/fastquant/../data/JFC_disclosures_1-1-2020_4-1-2020.csv

# %%
dpse
# Out:
# DisclosuresPSE('JFC', 'all', '1-1-2020', '4-1-2020', True, True)

# %%
dpse.company_disclosures.shape
# Out:
# (10, 7)

# %%
# summary of each disclosure 
dpse.company_disclosures.head()
# Out:
#                  Company Name                      Template Name  \
# 1  Jollibee Foods Corporation                      Press Release
# 2  Jollibee Foods Corporation                      Press Release
# 3  Jollibee Foods Corporation  Material Information/Transactions
# 4  Jollibee Foods Corporation            [Amend-1]Joint Ventures
# 5  Jollibee Foods Corporation  Material Information/Transactions
#
#   PSE Form Number Announce Date and Time Circular Number  \
# 1            4-31    2020-03-20 07:16:00     C02127-2020
# 2            4-31    2020-03-19 07:31:00     C02092-2020
# 3            4-30    2020-03-16 12:49:00     C01925-2020
# 4            4-22    2020-03-13 15:49:00     C01685-2020
# 5            4-30    2020-02-18 15:33:00     C01000-2020
#
#                             edge_no  \
# 1  a5df62b1a9558fe60de8473cebbd6407
# 2  6a7705d00b3e6fb50de8473cebbd6407
# 3  5b6a51f239ad5a6f0de8473cebbd6407
# 4  21b9a26e7aa00f960de8473cebbd6407
# 5  ed56abaed2893f830de8473cebbd6407
#
#                                                  url
# 1  https://edge.pse.com.ph/openDiscViewer.do?edge...
# 2  https://edge.pse.com.ph/openDiscViewer.do?edge...
# 3  https://edge.pse.com.ph/openDiscViewer.do?edge...
# 4  https://edge.pse.com.ph/openDiscViewer.do?edge...
# 5  https://edge.pse.com.ph/openDiscViewer.do?edge...

# %%
#get details in each disclosure given edge_no
dpse.disclosure_tables['a5df62b1a9558fe60de8473cebbd6407'].shape
# Out:
# (6, 2)

# %%
dpse.disclosures_combined['Subject of the Disclosure']
# Out:
# 0     Press Release: 2019 3rd Quarter Financial Results
# 1     JFC Takes 100% Ownership of Smashburger, Sees ...
# 2          Appointment of Chief Human Resources Officer
# 3                          Clarification of News Report
# 4     Press Release re: 2018 3rd Quarter Financial R...
#                             ...
# 64    Press Release: 2019 4th Quarter Financial Results
# 65          JFC Provides Statement on Business in China
# 66    JFC to Issue US$600 Million Guaranteed Senior ...
# 67    JFC to Issue US$600 Million Guaranteed Senior ...
# 68    JFC Mandates Banks for U.S.$ Senior Guaranteed...
# Name: Subject of the Disclosure, Length: 69, dtype: object

# %%
dpse.disclosures_combined['Background/Description of the Disclosure']
# Out:
# 0     JFC Reports its Q3 2019 Financial Results - Sa...
# 1     Jollibee Foods Corporation (“JFC”), the larges...
# 2     The Board of Directors disclosed today the app...
# 3                                                  None
# 4            JFC Nine Month Sales up 24%, Profit by 19%
#                             ...
# 64    JFC Same Store Sales Growth Improves, Gains fr...
# 65    Jollibee Foods Corporation makes the following...
# 66    Jollibee Foods Corporation (JFC, the “Guaranto...
# 67    Jollibee Foods Corporation (JFC, the “Guaranto...
# 68    Jollibee Worldwide Pte. Ltd. (JWPL, the “Issue...
# Name: Background/Description of the Disclosure, Length: 69, dtype: object

# %% [markdown]
# ## visualization

# %%
dpse.disclosure_types
# Out:
# array(['Press Release', 'Material Information/Transactions',
#        'Joint Ventures'], dtype=object)

# %%
#all
fig = dpse.plot_disclosures()
# Out:
# Pulling JFC stock data...
# Missing columns filled w/ NaN: ['volume']

# %% [markdown]
# # Investagrams disclosures

# %%
from fastquant import DisclosuresInvestagrams

# %%
dinv = DisclosuresInvestagrams(symbol='JFC', from_date='2018-01-01', to_date='2020-04-01')

# %%
dinv.dividends
# Out:
#             id       time    color label Cash Dividends            Ex-Date  \
# 0   timediv607 2018-04-19  #0496FF     D           1.14   Thu Apr 19, 2018
# 1   timediv786 2018-11-21  #0496FF     D           1.34   Wed Nov 21, 2018
# 2   timediv934 2019-04-23  #0496FF     D           1.23   Tue Apr 23, 2019
# 3  timediv1112 2019-11-21  #0496FF     D           1.35   Thu Nov 21, 2019
#
#          Record Date       Payment Date
# 0   Tue Apr 24, 2018   Wed May 09, 2018
# 1   Mon Nov 26, 2018   Mon Dec 10, 2018
# 2   Fri Apr 26, 2019   Thu May 09, 2019
# 3   Tue Nov 26, 2019   Tue Dec 10, 2019

# %%
dinv.earnings
# Out:
#                     id                time    color label  Total Revenue  \
# 0  timeearnings4820175 2018-04-11 06:26:00  #DC143C     E         133.39
# 1  timeearnings4820181 2018-05-10 00:32:00  #DC143C     E          35.05
# 2  timeearnings4820182 2018-08-14 01:21:00  #DC143C     E          40.78
# 3  timeearnings4820183 2018-11-12 05:18:00  #DC143C     E          40.49
# 4  timeearnings4820185 2019-04-11 00:33:00  #DC143C     E         164.35
# 5  timeearnings4820191 2019-05-15 06:37:00  #DC143C     E          40.62
# 6  timeearnings4820192 2019-08-05 07:13:00  #DC143C     E          44.22
# 7  timeearnings4820193 2019-11-14 03:46:00  #DC143C     E          45.17
#
#            Net Income    EPS               Date  Period Ending Revenue Unit  \
# 0      6.67B (10.23%)   6.58   Wed Apr 11, 2018   Dec 31, 2017            B
# 1      1.67B (13.14%)   1.66   Thu May 10, 2018   Mar 31, 2018            B
# 2       2.1B (10.55%)   2.07   Tue Aug 14, 2018   Jun 30, 2018            B
# 3      1.93B (26.90%)   1.87   Mon Nov 12, 2018   Sep 30, 2018            B
# 4      7.77B (16.47%)   7.66   Thu Apr 11, 2019   Dec 31, 2018            B
# 5     1.43B (-14.06%)   1.41   Wed May 15, 2019   Mar 31, 2019            B
# 6   985.48M (-53.10%)   1.03   Mon Aug 05, 2019   Jun 30, 2019            B
# 7       2.01B (4.48%)   1.71   Thu Nov 14, 2019   Sep 30, 2019            B
#
#    NI Unit  Net Income Amount Net Income YoY Growth (%)
# 0    B (%)               6.67                     10.23
# 1    B (%)               1.67                     13.14
# 2    B (%)               2.10                     10.55
# 3    B (%)               1.93                     26.90
# 4    B (%)               7.77                     16.47
# 5   B (-%)               1.43                    -14.06
# 6   M (-%)             985.48                    -53.10
# 7    B (%)               2.01                      4.48

# %% [markdown]
# # strategy

# %% [raw]
# !pip install backtrader[plotting]

# %% [raw]
# import pandas as pd
# from fastquant import backtest
#
# df = pd.read_csv("../data/JFC_20180101_20190110_DCV.csv")
#
# backtest('smac', df, fast_period=15, slow_period=40)

# %%
from fastquant import BaseStrategy, DisclosuresPSE

class DisclosuresStrategy(BaseStrategy):
    """
    Disclosure-based trading strategy

    Parameters
    ----------
    
    """

    params = (
        ("fast_period", 10),  # period for the fast moving average
        ("slow_period", 30),
    )

    def __init__(self):
        # Initialize global variables
        super().__init__()
        # Strategy level variables
        self.fast_period = self.params.fast_period
        self.slow_period = self.params.slow_period

        print("===Strategy level arguments===")
        print("fast_period :", self.fast_period)
        print("slow_period :", self.slow_period)
        sma_fast = bt.ind.SMA(period=self.fast_period)  # fast moving average
        sma_slow = bt.ind.SMA(period=self.slow_period)  # slow moving average
        self.crossover = bt.ind.CrossOver(
            sma_fast, sma_slow
        )  # crossover signal

    def buy_signal(self):
        return self.crossover > 0

    def sell_signal(self):
        return self.crossover < 0

# %% [raw]
# cols = "datetime open high low close volume openinterest".split()
#
# def parse_data_format(format):
#     data_format = {}
#     for n,col in enumerate(cols):
#         for f in format:
#             if col[0]==f:
#                 data_format[col] = n
#             else:
#                 data_format[col] = None
#     return data_format

# %%
DATA_FORMAT_MAPPING= {"dcv": {
                            "datetime": 0,
                            "open": None,
                            "high": None,
                            "low": None,
                            "close": 1,
                            "volume": 2,
                            "openinterest": None},
                      "dohlc": {
                            "datetime": 0,
                            "open": 1,
                            "high": 2,
                            "low": 3,
                            "close": 4,
                            "volume": None,
                            "openinterest": None
                          
                      }
                     }

# %%
from fastquant import get_stock_data

data = get_stock_data("JFC",
                  start_date="2019-01-01",
                  end_date="2020-01-01",
                  format="dohlc"
                 )
data.head()
# Out:
#              dt   open   high    low  close
# 2077 2019-01-02  292.0  295.8  291.8  293.0
# 2078 2019-01-03  292.8  294.2  290.8  292.0
# 2079 2019-01-04  293.8  310.4  293.2  309.0
# 2080 2019-01-07  309.0  324.2  309.0  323.0
# 2081 2019-01-08  323.0  323.0  316.0  321.0

# %%
from datetime import datetime
import pandas as pd
import backtrader as bt
import backtrader.feeds as btfeed

from fastquant import DATA_FILE, COMMISSION_PER_TRANSACTION, INIT_CASH
from fastquant import STRATEGY_MAPPING

cerebro = bt.Cerebro(stdstats=False)
# cerebro.addobserver(bt.observers.Broker)
# cerebro.addobserver(bt.observers.Trades)
# cerebro.addobserver(bt.observers.BuySell)

cerebro.addstrategy(DisclosuresStrategy,
                    #STRATEGY_MAPPING["rsi"], 
                    init_cash=INIT_CASH)

cerebro.broker.setcommission(commission=COMMISSION_PER_TRANSACTION)

pd_data = bt.feeds.PandasData(dataname=data, 
                            fromdate=datetime(2019, 1, 1),
                            todate=datetime(2020, 1, 1),
                            **DATA_FORMAT_MAPPING["dohlc"]
                              
                             )

cerebro.adddata(pd_data)
cerebro.broker.setcash(INIT_CASH)
# Allows us to set buy price based on next day closing
# (technically impossible, but reasonable assuming you use all your money to buy market at the end of the next day)
cerebro.broker.set_coc(True)
print("Starting Portfolio Value: %.2f" % cerebro.broker.getvalue())
cerebro.run()
print("Final Portfolio Value: %.2f" % cerebro.broker.getvalue())

# fig = pl.figure(figsize=(20, 10))
# cerebro.plot()
# Out:
# Starting Portfolio Value: 100000.00
# ===Global level arguments===
# init_cash : 100000
# buy_prop : 1
# sell_prop : 1
# ===Strategy level arguments===
# fast_period : 10
# slow_period : 30
# 2019-03-15, BUY CREATE, 316.20
# 2019-03-15, Cash: 100000.0
# 2019-03-15, Price: 316.2
# 2019-03-15, Buy prop size: 313
# 2019-03-15, Afforded size: 313
# 2019-03-15, Final size: 313
# 2019-03-18, BUY EXECUTED, Price: 316.20, Cost: 98970.60, Comm 742.28
# 2019-04-17, SELL CREATE, 303.00
# 2019-04-22, SELL EXECUTED, Price: 303.00, Cost: 98970.60, Comm 711.29
# 2019-04-22, OPERATION PROFIT, GROSS -4131.60, NET -5585.17
# 2019-06-24, BUY CREATE, 287.00
# 2019-06-24, Cash: 94414.82800000001
# 2019-06-24, Price: 287.0
# 2019-06-24, Buy prop size: 326
# 2019-06-24, Afforded size: 326
# 2019-06-24, Final size: 326
# 2019-06-25, BUY EXECUTED, Price: 287.00, Cost: 93562.00, Comm 701.71
# 2019-07-18, SELL CREATE, 279.80
# 2019-07-19, SELL EXECUTED, Price: 279.80, Cost: 93562.00, Comm 684.11
# 2019-07-19, OPERATION PROFIT, GROSS -2347.20, NET -3733.03
# 2019-10-14, BUY CREATE, 234.60
# 2019-10-14, Cash: 90681.80200000001
# 2019-10-14, Price: 234.6
# 2019-10-14, Buy prop size: 383
# 2019-10-14, Afforded size: 383
# 2019-10-14, Final size: 383
# 2019-10-15, BUY EXECUTED, Price: 234.60, Cost: 89851.80, Comm 673.89
# 2019-11-13, SELL CREATE, 202.60
# 2019-11-14, SELL EXECUTED, Price: 202.60, Cost: 89851.80, Comm 581.97
# 2019-11-14, OPERATION PROFIT, GROSS -12256.00, NET -13511.86
# 2019-12-16, BUY CREATE, 223.60
# 2019-12-16, Cash: 77169.945
# 2019-12-16, Price: 223.6
# 2019-12-16, Buy prop size: 342
# 2019-12-16, Afforded size: 342
# 2019-12-16, Final size: 342
# 2019-12-17, BUY EXECUTED, Price: 223.60, Cost: 76471.20, Comm 573.53
# Final Portfolio Value: 73997.21
# <img src="data:image/png;base64,..." width="431.53847736719854">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-40b15725bd25> in <module>
#      35
#      36 # fig = pl.figure(figsize=(20, 10))
# ---> 37 cerebro.plot()
#
# ~/miniconda3/envs/quant/lib/python3.8/site-packages/backtrader/cerebro.py in plot(self, plotter, numfigs, iplot, start, end, width, height, dpi, tight, use, **kwargs)
#     987         for stratlist in self.runstrats:
#     988             for si, strat in enumerate(stratlist):
# --> 989                 rfig = plotter.plot(strat, figid=si * 100,
#     990                                     numfigs=numfigs, iplot=iplot,
#     991                                     start=start, end=end, use=use)
#
# ~/miniconda3/envs/quant/lib/python3.8/site-packages/backtrader/plot/plot.py in plot(self, strategy, figid, numfigs, iplot, start, end, **kwargs)
#     218                         downinds=self.dplotsdown[ind])
#     219
# --> 220                 self.plotdata(data, self.dplotsover[data])
#     221
#     222                 for ind in self.dplotsdown[data]:
#
# ~/miniconda3/envs/quant/lib/python3.8/site-packages/backtrader/plot/plot.py in plotdata(self, data, indicators)
#     666         axdatamaster = None
#     667         if self.pinf.sch.volume and voloverlay:
# --> 668             volplot = self.plotvolume(
#     669                 data, opens, highs, lows, closes, volumes, vollabel)
#     670             axvol = self.pinf.daxis[data.volume]
#
# ~/miniconda3/envs/quant/lib/python3.8/site-packages/backtrader/plot/plot.py in plotvolume(self, data, opens, highs, lows, closes, volumes, label)
#     609
#     610                 volylim /= self.pinf.sch.volscaling
# --> 611                 ax.set_ylim(0, volylim, auto=True)
#     612             else:
#     613                 # plot a legend
#
# ~/miniconda3/envs/quant/lib/python3.8/site-packages/matplotlib/axes/_base.py in set_ylim(self, bottom, top, emit, auto, ymin, ymax)
#    3621         self._process_unit_info(ydata=(bottom, top))
#    3622         bottom = self._validate_converted_limits(bottom, self.convert_yunits)
# -> 3623         top = self._validate_converted_limits(top, self.convert_yunits)
#    3624
#    3625         old_bottom, old_top = self.get_ylim()
#
# ~/miniconda3/envs/quant/lib/python3.8/site-packages/matplotlib/axes/_base.py in _validate_converted_limits(self, limit, convert)
#    3156             if (isinstance(converted_limit, Real)
#    3157                     and not np.isfinite(converted_limit)):
# -> 3158                 raise ValueError("Axis limits cannot be NaN or Inf")
#    3159             return converted_limit
#    3160
#
# ValueError: Axis limits cannot be NaN or Inf
