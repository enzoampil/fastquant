# %%
from fastquant import CompanyDisclosures

# %% [markdown]
# ## fetching company disclosures

# %%
cd = CompanyDisclosures(symbol='JFC', start_date='5-1-2019')
# Out:
# Pulling JFC disclosures summary...
# Found 31 disclosures between 5-1-2019 & 04-12-2020 with 10 types:
# ['Declaration of Cash Dividends' 'Press Release'
#  'Material Information/Transactions' 'Joint Ventures'
#  'Change in Corporate Contact Details and/or Website'
#  'Substantial Acquisitions' 'Clarification of News Reports'
#  "Results of Annual or Special Stockholders' Meeting"
#  'Results of Organizational Meeting of Board of Directors'
#  "Notice of Annual or Special Stockholders' Meeting"]
# Pulling details in all JFC disclosures...
# the JSON object must be str, bytes or bytearray, not float
# the JSON object must be str, bytes or bytearray, not float
# Loaded: /home/jp/github/research/project/fastquant/fastquant/../data/JFC_disclosures_1-1-2019_04-12-2020.csv

# %%
cd
# Out:
# CompanyDisclosures('JFC', 'all', '5-1-2019', '04-12-2020', True, False)

# %%
# summary of each disclosure 
cd.company_disclosures.head()
# Out:
#                  Company Name                      Template Name  \
# 1  Jollibee Foods Corporation      Declaration of Cash Dividends
# 2  Jollibee Foods Corporation                      Press Release
# 3  Jollibee Foods Corporation                      Press Release
# 4  Jollibee Foods Corporation  Material Information/Transactions
# 5  Jollibee Foods Corporation            [Amend-1]Joint Ventures
#
#   PSE Form Number Announce Date and Time Circular Number  \
# 1             6-1    2020-04-07 10:16:00     C02610-2020
# 2            4-31    2020-03-20 07:16:00     C02127-2020
# 3            4-31    2020-03-19 07:31:00     C02092-2020
# 4            4-30    2020-03-16 12:49:00     C01925-2020
# 5            4-22    2020-03-13 15:49:00     C01685-2020
#
#                             edge_no  \
# 1  4b9121b34dd8b8e80de8473cebbd6407
# 2  a5df62b1a9558fe60de8473cebbd6407
# 3  6a7705d00b3e6fb50de8473cebbd6407
# 4  5b6a51f239ad5a6f0de8473cebbd6407
# 5  21b9a26e7aa00f960de8473cebbd6407
#
# ...

# %%
#get details in each disclosure given edge_no
cd.disclosure_tables['dfca1fdb569e514befdfc15ec263a54d']
# Out:
#                                         key  \
# 0                       Title of Each Class
# 1                 Subject of the Disclosure
# 2  Background/Description of the Disclosure
# 3                Other Relevant Information
# 4                                      Name
# 5                               Designation
#
#                                            value
# 0                                         COMMON
# 1  Press Release: 2018 Audited Financial Results
# 2     JFC Reports 2018 Audited Financial Results
# 3             Please see attached Press Release.
# 4                                Corazon Palomar
# 5                  Director, Investors Relations

# %%
cd.disclosures_combined['Subject of the Disclosure']
# Out:
# 0     JFC Mandates Banks for U.S.$ Senior Guaranteed...
# 1     Press Release: 2019 2nd Quarter Financial Results
# 2                          Clarification of News Report
# 3     JFC to Invest US$100M for the Acquisition of T...
# 4     JFC and Panda Restaurant Group, Inc. to bring ...
# 5                          Clarification of News Report
# 6               Results of Annual Stockholders’ Meeting
# 7     Results of Organizational Meeting of the Board...
# 8               Results of Annual Stockholders’ Meeting
# 9     Approval of amendments to the Senior Managemen...
# 10       Amended Notice of Annual Stockholders' Meeting
# 11    Press Release: 2019 1st Quarter Financial Results
# 12               Notice of annual stockholders' meeting
# 13    Approval of amendments to the Senior Managemen...
# 14        Press Release: 2018 Audited Financial Results
# 15                            Cash dividend declaration
# 16               Notice of annual stockholders' meeting
# ...

# %%
cd.disclosures_combined['Background/Description of the Disclosure']
# Out:
# 0     Jollibee Worldwide Pte. Ltd. (JWPL, the “Issue...
# 1     JFC Sales Growth Improves, Eyes Profit Recover...
# 2                                                  None
# 3     Jollibee Foods Corporation (JFC), one of Asia’...
# 4     Jollibee Foods Corporation (JFC), one of the l...
# 5                                                  None
# 6               Results of Annual Stockholders’ Meeting
# 7     Results of Organizational Meeting of the Board...
# 8               Results of Annual Stockholders’ Meeting
# 9     Upon recommendation of the Compensation Commit...
# 10    Amended Notice of Annual Stockholders' Meeting...
# 11    JFC Sales Up 18% in Quarter 1, To Open 500 New...
# 12    Notice of annual stockholders' meeting and app...
# 13    Upon recommendation of the Compensation Commit...
# 14           JFC Reports 2018 Audited Financial Results
# 15    Jollibee Foods Corporation (JFC) announced tha...
# 16    Notice of annual stockholders' meeting and app...
# ...

# %% [markdown]
# ## visualization

# %%
cd.disclosure_types
# Out:
# array(['Declaration of Cash Dividends', 'Press Release',
#        'Material Information/Transactions', 'Joint Ventures',
#        'Change in Corporate Contact Details and/or Website',
#        'Substantial Acquisitions', 'Clarification of News Reports',
#        "Results of Annual or Special Stockholders' Meeting",
#        'Results of Organizational Meeting of Board of Directors',
#        "Notice of Annual or Special Stockholders' Meeting"], dtype=object)

# %%
#all
fig = cd.plot_disclosures()
# Out:
# 0it [00:00, ?it/s]
# Pulling JFC stock data...
# 348it [02:06,  2.42it/s]

# %%
fig = cd.plot_disclosures(disclosure_type='Substantial Acquisitions', data_type='volume')
