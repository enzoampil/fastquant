# %% [markdown]
# <a href="https://colab.research.google.com/github/enzoampil/psequant/blob/master/examples/psequant_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install psequant
# Out:
# Requirement already up-to-date: psequant in /usr/local/lib/python3.6/dist-packages (0.1.2.1)
# Requirement already satisfied, skipping upgrade: backtrader==1.9.74.123 in /usr/local/lib/python3.6/dist-packages (from psequant) (1.9.74.123)
# Requirement already satisfied, skipping upgrade: six==1.13.0 in /usr/local/lib/python3.6/dist-packages (from psequant) (1.13.0)
# Requirement already satisfied, skipping upgrade: pytz==2019.3 in /usr/local/lib/python3.6/dist-packages (from psequant) (2019.3)
# Requirement already satisfied, skipping upgrade: requests-oauthlib==1.3.0 in /usr/local/lib/python3.6/dist-packages (from psequant) (1.3.0)
# Requirement already satisfied, skipping upgrade: urllib3==1.25.7 in /usr/local/lib/python3.6/dist-packages (from psequant) (1.25.7)
# Requirement already satisfied, skipping upgrade: requests==2.22.0 in /usr/local/lib/python3.6/dist-packages (from psequant) (2.22.0)
# Requirement already satisfied, skipping upgrade: beautifulsoup4==4.8.2 in /usr/local/lib/python3.6/dist-packages (from psequant) (4.8.2)
# Requirement already satisfied, skipping upgrade: lxml==4.4.2 in /usr/local/lib/python3.6/dist-packages (from psequant) (4.4.2)
# Requirement already satisfied, skipping upgrade: pandas==0.25.3 in /usr/local/lib/python3.6/dist-packages (from psequant) (0.25.3)
# Requirement already satisfied, skipping upgrade: tweepy==3.8.0 in /usr/local/lib/python3.6/dist-packages (from psequant) (3.8.0)
# Requirement already satisfied, skipping upgrade: certifi==2019.11.28 in /usr/local/lib/python3.6/dist-packages (from psequant) (2019.11.28)
# Requirement already satisfied, skipping upgrade: bs4==0.0.1 in /usr/local/lib/python3.6/dist-packages (from psequant) (0.0.1)
# Requirement already satisfied, skipping upgrade: numpy==1.18.0 in /usr/local/lib/python3.6/dist-packages (from psequant) (1.18.0)
# Requirement already satisfied, skipping upgrade: chardet==3.0.4 in /usr/local/lib/python3.6/dist-packages (from psequant) (3.0.4)
# Requirement already satisfied, skipping upgrade: PySocks==1.7.1 in /usr/local/lib/python3.6/dist-packages (from psequant) (1.7.1)
# Requirement already satisfied, skipping upgrade: black==19.10b0 in /usr/local/lib/python3.6/dist-packages (from psequant) (19.10b0)
# Requirement already satisfied, skipping upgrade: oauthlib==3.1.0 in /usr/local/lib/python3.6/dist-packages (from psequant) (3.1.0)
# Requirement already satisfied, skipping upgrade: matplotlib==3.1.2 in /usr/local/lib/python3.6/dist-packages (from psequant) (3.1.2)
# Requirement already satisfied, skipping upgrade: python-dateutil==2.8.1 in /usr/local/lib/python3.6/dist-packages (from psequant) (2.8.1)
# Requirement already satisfied, skipping upgrade: idna==2.8 in /usr/local/lib/python3.6/dist-packages (from psequant) (2.8)
# Requirement already satisfied, skipping upgrade: soupsieve==1.9.5 in /usr/local/lib/python3.6/dist-packages (from psequant) (1.9.5)
# Requirement already satisfied, skipping upgrade: click>=6.5 in /usr/local/lib/python3.6/dist-packages (from black==19.10b0->psequant) (7.0)
# Requirement already satisfied, skipping upgrade: toml>=0.9.4 in /usr/local/lib/python3.6/dist-packages (from black==19.10b0->psequant) (0.10.0)
# Requirement already satisfied, skipping upgrade: pathspec<1,>=0.6 in /usr/local/lib/python3.6/dist-packages (from black==19.10b0->psequant) (0.7.0)
# Requirement already satisfied, skipping upgrade: typed-ast>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from black==19.10b0->psequant) (1.4.0)
# Requirement already satisfied, skipping upgrade: regex in /usr/local/lib/python3.6/dist-packages (from black==19.10b0->psequant) (2019.12.9)
# Requirement already satisfied, skipping upgrade: appdirs in /usr/local/lib/python3.6/dist-packages (from black==19.10b0->psequant) (1.4.3)
# Requirement already satisfied, skipping upgrade: attrs>=18.1.0 in /usr/local/lib/python3.6/dist-packages (from black==19.10b0->psequant) (19.3.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib==3.1.2->psequant) (2.4.5)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib==3.1.2->psequant) (1.1.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib==3.1.2->psequant) (0.10.0)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from kiwisolver>=1.0.1->matplotlib==3.1.2->psequant) (42.0.2)

# %%
from psequant import get_pse_data
df = get_pse_data('JFC', '2018-01-01', '2019-01-01')
df.head()
# Out:
# Stock table exists!
# Reading stock_table.csv ...
#              open   high    low  close        value
# dt
# 2018-01-03  253.4  256.8  253.0  255.4  190253754.0
# 2018-01-04  255.4  255.4  253.0  255.0  157152856.0
# 2018-01-05  255.6  257.4  255.0  255.0  242201952.0
# 2018-01-08  257.4  259.0  253.4  256.0  216069242.0
# 2018-01-09  256.0  258.0  255.0  255.8  250188588.0

# %%
df.close.plot(figsize=(10, 6))
